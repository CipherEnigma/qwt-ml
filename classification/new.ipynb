# %%
# !python qwt_resnet_group_conv_only_percentile.py \
    --model resnet50 \
    --data_dir imagenet1k \
    --w_bits 4 \
    --a_bits 4 \
    --kernel_size 1 \
    --factor 64 \
    --start_block 0 \
    --batch_size 8 \
    --num_workers 2

# %%
# !python qwt_resnet_group_conv_only_percentile.py \
    --model resnet50 \
    --data_dir imagenet1k \
    --w_bits 6 \
    --a_bits 6 \
    --kernel_size 1 \
    --factor 64 \
    --start_block 0 \
    --batch_size 8 \
    --num_workers 2

# %%
# !python qwt_vit_and_deit.py \
    --model vit_base \
    --data_dir imagenet1k \
    --w_bits 4 \
    --a_bits 4 \
    --start_block 0 \
    --batch_size 8

# %%
# !python qwt_vit_and_deit.py \
    --model vit_base \
    --data_dir magenet1k \
    --w_bits 6 \
    --a_bits 6 \
    --start_block 0 \
    --batch_size 8

# %%
# !python qwt_vit_and_deit.py \
    --model deit_tiny \
    --data_dir imagenet1k \
    --w_bits 4 \
    --a_bits 4 \
    --start_block 0 \
    --batch_size 8

# %%
# !python qwt_vit_and_deit.py \
    --model deit_tiny \
    --data_dir imagenet1k \
    --w_bits 6 \
    --a_bits 6 \
    --start_block 0 \
    --batch_size 8

# %%
# !python qwt_swin.py \
    --model swin_tiny \
    --data_dir imagenet1k \
    --w_bits 4 \
    --a_bits 4 \
    --start_block 0 \
    --batch_size 8

# %%
# !python qwt_swin.py \
    --model swin_tiny \
    --data_dir imagenet1k \
    --w_bits 6 \
    --a_bits 6 \
    --start_block 0 \
    --batch_size 8
